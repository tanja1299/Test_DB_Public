# %% [markdown]
# # TEST NOTEBOOK
#
# Dieses Notebook ist als Test für verschiedene Funktionen gedacht:
# 1) Testen verschiedener Python Befehle
# 2) Testen, ob Link zu diesem Notebook erstellt und von anderen geöffnet/bearbeitet werden kann

# %%
print('Rechnen 1')
1 + 1
# Out:
# Rechnen 1
# 2

# %%
print('Rechnen 2')
(7 + 2) / 3
# Out:
# Rechnen 2
# 3.0

# %%
print('Variablen anlegen')
r = 15 - 7
# Out:
# Variablen anlegen

# %%
print('Variablen öffnen')
r
# Out:
# Variablen öffnen
# 8

# %% [markdown]
# # Bearbeitung über Binder möglich?

# %% [markdown]
# Anweisung: Gib bitte in die nächste Zeile '(12 + 6)/4' ein und speicher das Ergebnis in der Variable x. Lass danach den nächsten Befehl in der darauffolgenden Zeile laufen. Funktioniert´s?

# %%
x =

# %%
x
# Out:
# 1

# %% [markdown]
# # Laden von Excel Datei möglich?

# %%
import pandas as pd

# %%
db = pd.read_excel("Durchflussmessungen an Messstellen in Bayern ab 2017_aufbereitet WAL.xlsx")

# %%
db.head(7)
# Out:
#   Wasserwirtschaftsamt Messstellen-Nr.     Messstellenname      Datum  \
# 0          WWA Ansbach        24213806       Seemannsmühle 2017-10-18
# 1          WWA Ansbach        24213103  Ansbach_Hennenbach 2017-10-23
# 2          WWA Ansbach        24219008           Bruckberg 2017-10-23
# 3          WWA Ansbach        24218504         Lentersdorf 2017-10-23
# 4          WWA Ansbach        24211414   Mitteldachstetten 2017-10-23
# 5          WWA Ansbach        24211505         Oberheßbach 2017-10-23
# 6          WWA Ansbach        13424901           Bechhofen 2017-10-24
#
#     Uhrzeit Messung \nStatus Spalte1  Spalte2  Wasserstand\nW\n[m]  \
# 0  08:45:00        bestätigt  falsch      NaN                 1.37
# 1  14:00:00        bestätigt  falsch      NaN                 1.14
# 2  08:30:00        bestätigt  falsch      NaN                 1.37
# 3  09:10:00        bestätigt  falsch      NaN                 1.27
# 4  11:55:00        bestätigt  falsch      NaN                 1.08
# ...

# %%
db.tail(7)
# Out:
#       Wasserwirtschaftsamt Messstellen-Nr.    Messstellenname      Datum  \
# 10924         WWA Weilheim        16336555  Lenggries_Arzbach 2020-08-04
# 10925         WWA Weilheim        16610709       Oberammergau 2020-08-04
# 10926         WWA Weilheim        16001303       Rißbachdüker 2020-08-04
# 10927         WWA Weilheim        16145008       Rißbachklamm 2020-08-04
# 10928         WWA Weilheim        16667604          Seeshaupt 2020-08-04
# 10929         WWA Weilheim        16004403           Puppling 2020-08-05
# 10930         WWA Weilheim        16404900         Schlehdorf 2020-08-05
#
#         Uhrzeit Messung \nStatus Spalte1  Spalte2  Wasserstand\nW\n[m]  \
# 10924  15:14:00        bestätigt      Ok      NaN              0.37000
# 10925  09:20:00        bestätigt      Ok      NaN              2.07572
# 10926  08:37:00        bestätigt      Ok      NaN              1.29000
# 10927  07:16:00      unbestätigt      Ok      NaN              2.23000
# ...

# %%
pip install watermark
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for watermark from https://files.pythonhosted.org/packages/67/ee/32fec350c20ff060064d058c37df53dd1fad74dfea9532faf2868b0512b5/watermark-2.4.3-py2.py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext watermark

# %%
# %watermark --machine --python --packages pandas
# Out:
# Python implementation: CPython
# Python version       : 3.11.5
# IPython version      : 8.15.0
#
# pandas: 2.0.3
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 142 Stepping 9, GenuineIntel
# CPU cores   : 4
# Architecture: 64bit
